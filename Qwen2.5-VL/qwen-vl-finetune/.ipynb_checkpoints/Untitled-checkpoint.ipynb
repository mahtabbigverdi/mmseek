# %%
import argparse
import torch
from transformers import AutoProcessor, Qwen2_5_VLForConditionalGeneration, AutoTokenizer
from qwen_vl_utils import process_vision_info
from tqdm import tqdm
import os
# Optional: only if you're using external LoRA adapters (kept separate)
try:
    from peft import PeftModel
    PEFT_AVAILABLE = True
except Exception:
    PEFT_AVAILABLE = False
# DEFAULT_QWEN25_VL_TEMPLATE = "{% set image_count = namespace(value=0) %}{% set video_count = namespace(value=0) %}{% for message in messages %}{% if loop.first and message['role'] != 'system' %}<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n{% endif %}<|im_start|>{{ message['role'] }}\n{% if message['content'] is string %}{{ message['content'] }}<|im_end|>\n{% else %}{% for content in message['content'] %}{% if content['type'] == 'image' or 'image' in content or 'image_url' in content %}{% set image_count.value = image_count.value + 1 %}{% if add_vision_id %}Picture {{ image_count.value }}: {% endif %}<|vision_start|><|image_pad|><|vision_end|>{% elif content['type'] == 'video' or 'video' in content %}{% set video_count.value = video_count.value + 1 %}{% if add_vision_id %}Video {{ video_count.value }}: {% endif %}<|vision_start|><|video_pad|><|vision_end|>{% elif 'text' in content %}{{ content['text'] }}{% endif %}{% endfor %}<|im_end|>\n{% endif %}{% endfor %}{% if add_generation_prompt %}<|im_start|>assistant\n{% endif %}"

def load_model_and_processor(
    model_id_or_path: str,
    lora_adapter: str | None = None,
    merge_lora: bool = False,
    device_map: str = "auto",
    dtype: torch.dtype | str = "auto",
):
    """
    model_id_or_path: your finetuned model (HF repo or local folder). If you merged LoRA already, just point here.
    lora_adapter: path or HF repo of LoRA adapter if NOT merged.
    merge_lora: set True to merge-and-unload LoRA into base weights for inference.
    """
    model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
        model_id_or_path,
        torch_dtype=dtype,
        device_map=device_map,
    )

    if lora_adapter:
        if not PEFT_AVAILABLE:
            raise RuntimeError("peft not installed, but lora_adapter provided.")
        model = PeftModel.from_pretrained(model, lora_adapter)
        if merge_lora:
            # Permanently merge LoRA for faster inference
            model = model.merge_and_unload()

    processor = AutoProcessor.from_pretrained(model_id_or_path)  # has the image_processor inside
    tok = AutoTokenizer.from_pretrained(model_id_or_path, use_fast=False)

    processor.tokenizer = tok 
    processor.chat_template = tok.chat_template

    return model, processor


@torch.inference_mode()
def generate_greedy(model, processor, messages,new_text, max_new_tokens):
 
    # Prepare inputs using the official chat template and utils
    text = processor.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    )
    # 
    text += new_text
    # print(text)
    image_inputs, video_inputs = process_vision_info(messages)

    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    ).to(model.device)
    # Deterministic decoding: no sampling, temperature ignored (set to 0 for clarity)
    gen_ids = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False, 
        temperature=0,        
        num_beams=1,
        use_cache=True,
    )
    # Trim the prompt part before decoding
    trimmed = [out[len(inp):] for inp, out in zip(inputs.input_ids, gen_ids)]
    out_text = processor.batch_decode(trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False)
    # print(out_text)
    # out_text = processor.batch_decode(gen_ids)
    return out_text[0]


def eval(model, processor, prompt,new_text, image, max_new_tokens=2048):
    messages = [{
        "role": "user",
        "content": [
            {"type": "image", "image": image},
            {"type": "text", "text": prompt},
        ],
    }]
    output = generate_greedy(model, processor, messages,new_text, max_new_tokens=max_new_tokens)
    return output


def save_evals(model, processor ,model_id):
    import json
    import random
    with open("/mmfs1/gscratch/krishna/mahtab/mmseek/vqgan/validation_2points_sideview_pathtracing_codes_ade_vqgan_f16_1024.json", "r") as f:
        codes = json.load(f)
    val_data_path  =  "/mmfs1/gscratch/krishna/mahtab/mmseek/Data/validation_path_tracing_2point.json"
    # val_data_path  =  "/mmfs1/gscratch/krishna/mahtab/mmseek/Data/temp_validation.json"
    
    answers = {}
    with open(val_data_path, 'r') as f:
        val_data = json.load(f)
    for item in val_data:
        index = item['id']
        image_path = item['image']
        prompt = item['conversations'][0]['value'].replace('\n', '')
        side = "left" if "left" in prompt else "right"
        code = codes[f"{index}.png"]
        # code = "<RGB_START>" + "".join([f"<RGB_{i}>" for i in code])     + "<RGB_END>"
        code = "<RGB_START>" + "".join([f"<RGB_{random.randint(0, 1023)}>" for i in range(256)])     + "<RGB_END>"
        
        new_text = f"\nOn {side} side at midpoint M1, I can imagine this view: "+ code
        
        output = eval(model, processor, prompt, new_text, image_path, max_new_tokens=2048)
        answers[index] = output
        # print(f"Index: {index}")
    save_path = f"/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/{model_id}_path_tracing_2point_answerswithgtt.json"
    with open(save_path, 'w') as f:
        json.dump(answers, f, indent=4)

    
        

def main(model_name):
    parser = argparse.ArgumentParser()
    lora_adapter = None
    merge_lora = False

    dtype = torch.bfloat16 if torch.cuda.is_available() else "auto"
    model, processor = load_model_and_processor(
        model_name,
        lora_adapter=lora_adapter,
        merge_lora=merge_lora,
        dtype=dtype,
        device_map="auto"
    )
    save_evals(model, processor, model_name.split("/")[-1])

# %%
if __name__ == "__main__":
    #get model name from command line
    model_name = "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/checkpoints/7b_path_tracing_2points_vqgan1024_mm_10epochs_lr5e-5_random"
    main(model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /gscratch/krishna/mahtab/miniconda3/envs/qwen2vl/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(

# %%
import argparse
import torch
from transformers import AutoProcessor, Qwen2_5_VLForConditionalGeneration, AutoTokenizer
from qwen_vl_utils import process_vision_info
from tqdm import tqdm
import os
# Optional: only if you're using external LoRA adapters (kept separate)
try:
    from peft import PeftModel
    PEFT_AVAILABLE = True
except Exception:
    PEFT_AVAILABLE = False
# DEFAULT_QWEN25_VL_TEMPLATE = "{% set image_count = namespace(value=0) %}{% set video_count = namespace(value=0) %}{% for message in messages %}{% if loop.first and message['role'] != 'system' %}<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n{% endif %}<|im_start|>{{ message['role'] }}\n{% if message['content'] is string %}{{ message['content'] }}<|im_end|>\n{% else %}{% for content in message['content'] %}{% if content['type'] == 'image' or 'image' in content or 'image_url' in content %}{% set image_count.value = image_count.value + 1 %}{% if add_vision_id %}Picture {{ image_count.value }}: {% endif %}<|vision_start|><|image_pad|><|vision_end|>{% elif content['type'] == 'video' or 'video' in content %}{% set video_count.value = video_count.value + 1 %}{% if add_vision_id %}Video {{ video_count.value }}: {% endif %}<|vision_start|><|video_pad|><|vision_end|>{% elif 'text' in content %}{{ content['text'] }}{% endif %}{% endfor %}<|im_end|>\n{% endif %}{% endfor %}{% if add_generation_prompt %}<|im_start|>assistant\n{% endif %}"

def load_model_and_processor(
    model_id_or_path: str,
    lora_adapter: str | None = None,
    merge_lora: bool = False,
    device_map: str = "auto",
    dtype: torch.dtype | str = "auto",
):
    """
    model_id_or_path: your finetuned model (HF repo or local folder). If you merged LoRA already, just point here.
    lora_adapter: path or HF repo of LoRA adapter if NOT merged.
    merge_lora: set True to merge-and-unload LoRA into base weights for inference.
    """
    model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
        model_id_or_path,
        torch_dtype=dtype,
        device_map=device_map,
    )

    if lora_adapter:
        if not PEFT_AVAILABLE:
            raise RuntimeError("peft not installed, but lora_adapter provided.")
        model = PeftModel.from_pretrained(model, lora_adapter)
        if merge_lora:
            # Permanently merge LoRA for faster inference
            model = model.merge_and_unload()

    processor = AutoProcessor.from_pretrained(model_id_or_path)  # has the image_processor inside
    tok = AutoTokenizer.from_pretrained(model_id_or_path, use_fast=False)

    processor.tokenizer = tok 
    processor.chat_template = tok.chat_template

    return model, processor


@torch.inference_mode()
def generate_greedy(model, processor, messages,old, max_new_tokens):
    """
    messages: Chat-style list with mixed text and images, e.g.
      [{
         "role": "user",
         "content": [
            {"type": "image", "image": "file:///path/to/img.jpg" or URL or PIL.Image},
            {"type": "text", "text": "Your prompt here"}
         ]
      }]
    """
    # Prepare inputs using the official chat template and utils
    text = processor.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    )
    image_inputs, video_inputs = process_vision_info(messages)
    text += old
    # print(text)
    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    ).to(model.device)
    # Deterministic decoding: no sampling, temperature ignored (set to 0 for clarity)
    gen_ids = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False, 
        temperature=0,        
        num_beams=1,
        use_cache=True,
    )
    # Trim the prompt part before decoding
    trimmed = [out[len(inp):] for inp, out in zip(inputs.input_ids, gen_ids)]
    out_text = processor.batch_decode(trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False)
    # out_text = processor.batch_decode(gen_ids)
    return out_text[0]


def eval(model, processor, prompt, old, image, max_new_tokens=2048):
    messages = [{
        "role": "user",
        "content": [
            {"type": "image", "image": image},
            {"type": "text", "text": prompt},
        ],
    }]
    output = generate_greedy(model, processor, messages,old, max_new_tokens=max_new_tokens)
    return output


def save_evals(model, processor ,model_id):
    import numpy as np
    import json
    import random
    with open("/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/3b_vqvae_long_lr5e-5_random_blink3_long.json", "r") as f:
        previous = json.load(f)
    codes = np.load("/gscratch/krishna/mahtab/AiT/vae/blink_codes_320.npy", allow_pickle=True).item()
    blink3 ={}
    # blink4 ={}
    # blink5 ={}
    for i in tqdm(range(124)):
        print(f"Evaluating image {i}")
        prompt = "Multiple points are circled on the image, labeled by letters beside each circle. Which point is the closest to the camera?\nTo answer this question, let's think through it step by step, and we know the image is 336 x 336. First, what are the coordinates of points in the image? Second, what is the depth map for the image? Which point has a higher pixel value on the depth map? Remember, higher values indicate that the point is closer to the camera."
        typ ="long"
        # prompt = "Multiple points are circled on the image, labeled by letters beside each circle. Which point is the closest to the camera?"
        # typ = "short"
        # prompt = "Multiple points are circled on the image, labeled by letters beside each circle. Which point is the closest to the camera?\nTo answer this question, let's think through it step by step, and we know the image is 336 x 336. First, what are the coordinates of points in the image? Which point has a higher pixel value on the depth map? Remember, higher values indicate that the point is closer to the camera."
        # typ = "onlytext"
        # prompt = "What is the depth map for this image?"
        # typ = "depth"
        # prompt = "What do you see in this image?"
        # typ = "free"
        ##blink3
        image = f"/mmfs1/gscratch/krishna/mahtab/Aurora-perception/Data/evals/hardblink/images/blink3pointscenter/{i}.png"
        assert os.path.exists(image), f"Image {image} does not exist"
        try:
            old =  previous[str(i)]
            # code = codes[f"{i}_depth.png"]
            code = "<DEPTH_START>" +  "".join([f"<DEPTH_{random.randint(0, 127)}>" for i in range(100)])   + "<DEPTH_END>"
            old =  old.split("<DEPTH_START>")[0] + code
            # old =  old.split("<DEPTH_END>")[0] + "<DEPTH_END>"
            output = eval(model, processor, prompt, old, image)
            blink3[i] = output
        except Exception as e:
            pass
        # print(output)
        ##blink4
        # image = f"/mmfs1/gscratch/krishna/mahtab/Aurora-perception/Data/evals/hardblink/images/blink4pointscenter/{i}.png"
        # assert os.path.exists(image), f"Image {image} does not exist"
        # try:
        #     old =  previous[str(i)]
        #     code = codes[f"{i}_depth.png"]
        #     # code = "<DEPTH_START>" +  "".join([f"<DEPTH_{random.randint(0, 127)}>" for i in range(100)])   + "<DEPTH_END>"
        #     old =  old.split("<DEPTH_START>")[0] + code
        #     # old =  old.split("<DEPTH_END>")[0] + "<DEPTH_END>"
        #     output = eval(model, processor, prompt, old, image)
        #     blink4[i] = output
        # except Exception as e:
        #     pass
        # ##blink5
        # image = f"/mmfs1/gscratch/krishna/mahtab/Aurora-perception/Data/evals/hardblink/images/blink5pointscenter/{i}.png"
        # assert os.path.exists(image), f"Image {image} does not exist"
    
        # old =  previous[str(i)]
        # # code = codes[f"{i}_depth.png"]
        # code = "<DEPTH_START>" +  "".join([f"<DEPTH_{random.randint(0, 127)}>" for i in range(100)])   + "<DEPTH_END>"
        # old =  old.split("<DEPTH_START>")[0] + code
        # # old =  old.split("<DEPTH_END>")[0] + "<DEPTH_END>"
        # output = eval(model, processor, prompt, old, image)
        # blink5[i] = output
        
    
        # import json
        with open(f"/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/{model_id}_blink3_{typ}_withrandom.json", "w") as f:
            json.dump(blink3, f)
        # with open(f"/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/{model_id}_blink4_{typ}_withgt.json", "w") as f:
        #     json.dump(blink4, f)
        # with open(f"/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/{model_id}_blink5_{typ}_withrandom.json", "w") as f:
        #     json.dump(blink5, f)
    
    # print(len(blink3), len(blink4), len(blink5))






        





def main():
    parser = argparse.ArgumentParser()
    lora_adapter = None
    merge_lora = False

    model_name =  "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/checkpoints/3b_vqvae_long_lr5e-5_random"  
    # model_name = "Qwen/Qwen2.5-VL-7B-Instruct"
    dtype = torch.bfloat16 if torch.cuda.is_available() else "auto"
    model, processor = load_model_and_processor(
        model_name,
        lora_adapter=lora_adapter,
        merge_lora=merge_lora,
        dtype=dtype,
        device_map="auto"
    )
    save_evals(model, processor, model_name.split("/")[-1])



if __name__ == "__main__":
    main()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|                                                 | 0/124 [00:00<?, ?it/s]/gscratch/krishna/mahtab/miniconda3/envs/qwen2vl/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Evaluating image 0
#   1%|▎                                        | 1/124 [00:01<02:54,  1.41s/it]
# Evaluating image 1
#   2%|▋                                        | 2/124 [00:02<02:51,  1.41s/it]
# Evaluating image 2
#   2%|▉                                        | 3/124 [00:04<02:49,  1.40s/it]
# Evaluating image 3
#   3%|█▎                                       | 4/124 [00:05<02:48,  1.41s/it]
# Evaluating image 4
#   4%|█▋                                       | 5/124 [00:07<02:47,  1.41s/it]
# Evaluating image 5
#   5%|█▉                                       | 6/124 [00:08<02:46,  1.41s/it]
# Evaluating image 6
#   6%|██▎                                      | 7/124 [00:09<02:44,  1.41s/it]
# Evaluating image 7
#   6%|██▋                                      | 8/124 [00:11<02:50,  1.47s/it]
# Evaluating image 8
#   7%|██▉                                      | 9/124 [00:13<02:58,  1.55s/it]
# Evaluating image 9
#   8%|███▏                                    | 10/124 [00:14<03:02,  1.60s/it]
# Evaluating image 10
#   9%|███▌                                    | 11/124 [00:16<03:05,  1.64s/it]
# Evaluating image 11
#  10%|███▊                                    | 12/124 [00:18<03:06,  1.66s/it]
# Evaluating image 12
#  10%|████▏                                   | 13/124 [00:20<03:06,  1.68s/it]
# Evaluating image 13
#  11%|████▌                                   | 14/124 [00:21<03:05,  1.69s/it]
# Evaluating image 14
#  12%|████▊                                   | 15/124 [00:23<03:05,  1.70s/it]
# Evaluating image 15
#  13%|█████▏                                  | 16/124 [00:25<03:04,  1.71s/it]
# Evaluating image 16
#  14%|█████▍                                  | 17/124 [00:26<03:03,  1.72s/it]
# Evaluating image 17
#  15%|█████▊                                  | 18/124 [00:28<03:02,  1.72s/it]
# Evaluating image 18
#  15%|██████▏                                 | 19/124 [00:30<03:00,  1.72s/it]
# Evaluating image 19
#  16%|██████▍                                 | 20/124 [00:32<02:59,  1.72s/it]
# Evaluating image 20
#  17%|██████▊                                 | 21/124 [00:33<02:57,  1.73s/it]
# Evaluating image 21
#  18%|███████                                 | 22/124 [00:35<02:43,  1.60s/it]
# Evaluating image 22
#  19%|███████▍                                | 23/124 [00:36<02:32,  1.51s/it]
# Evaluating image 23
#  19%|███████▋                                | 24/124 [00:37<02:24,  1.44s/it]
# Evaluating image 24
#  20%|████████                                | 25/124 [00:39<02:18,  1.40s/it]
# Evaluating image 25
#  21%|████████▍                               | 26/124 [00:40<02:13,  1.36s/it]
# Evaluating image 26
#  22%|████████▋                               | 27/124 [00:41<02:10,  1.35s/it]
# Evaluating image 27
#  23%|█████████                               | 28/124 [00:42<02:07,  1.33s/it]
# Evaluating image 28
#  23%|█████████▎                              | 29/124 [00:44<02:05,  1.32s/it]
# Evaluating image 29
#  24%|█████████▋                              | 30/124 [00:45<02:03,  1.31s/it]
# Evaluating image 30
#  25%|██████████                              | 31/124 [00:46<02:01,  1.31s/it]
# Evaluating image 31
#  26%|██████████▎                             | 32/124 [00:48<01:59,  1.30s/it]
# Evaluating image 32
#  27%|██████████▋                             | 33/124 [00:49<01:58,  1.30s/it]
# Evaluating image 33
#  27%|██████████▉                             | 34/124 [00:50<01:57,  1.30s/it]
# Evaluating image 34
#  28%|███████████▎                            | 35/124 [00:52<01:58,  1.33s/it]
# Evaluating image 35
#  29%|███████████▌                            | 36/124 [00:53<01:55,  1.31s/it]
# Evaluating image 36
#  30%|███████████▉                            | 37/124 [00:54<01:53,  1.31s/it]
# Evaluating image 37
#  31%|████████████▎                           | 38/124 [00:55<01:51,  1.30s/it]
# Evaluating image 38
#  31%|████████████▌                           | 39/124 [00:57<01:50,  1.30s/it]
# Evaluating image 39
#  32%|████████████▉                           | 40/124 [00:58<01:50,  1.31s/it]
# Evaluating image 40
#  33%|█████████████▏                          | 41/124 [00:59<01:48,  1.30s/it]
# Evaluating image 41
#  34%|█████████████▌                          | 42/124 [01:01<01:46,  1.30s/it]
# Evaluating image 42
#  35%|█████████████▊                          | 43/124 [01:02<01:45,  1.30s/it]
# Evaluating image 43
#  35%|██████████████▏                         | 44/124 [01:03<01:43,  1.29s/it]
# Evaluating image 44
#  36%|██████████████▌                         | 45/124 [01:05<01:41,  1.29s/it]
# Evaluating image 45
#  37%|██████████████▊                         | 46/124 [01:06<01:40,  1.29s/it]
# Evaluating image 46
#  38%|███████████████▏                        | 47/124 [01:07<01:39,  1.29s/it]
# Evaluating image 47
#  39%|███████████████▍                        | 48/124 [01:08<01:38,  1.29s/it]
# Evaluating image 48
#  40%|███████████████▊                        | 49/124 [01:10<01:36,  1.29s/it]
# Evaluating image 49
#  40%|████████████████▏                       | 50/124 [01:11<01:35,  1.29s/it]
# Evaluating image 50
# Evaluating image 112
#  91%|███████████████████████████████████▌   | 113/124 [02:38<00:15,  1.38s/it]
# Evaluating image 113
#  92%|███████████████████████████████████▊   | 114/124 [02:40<00:13,  1.38s/it]
# Evaluating image 114
#  93%|████████████████████████████████████▏  | 115/124 [02:41<00:12,  1.38s/it]
# Evaluating image 115
#  94%|████████████████████████████████████▍  | 116/124 [02:42<00:11,  1.38s/it]
# Evaluating image 116
#  94%|████████████████████████████████████▊  | 117/124 [02:44<00:09,  1.38s/it]
# Evaluating image 117
#  95%|█████████████████████████████████████  | 118/124 [02:45<00:08,  1.38s/it]
# Evaluating image 118
#  96%|█████████████████████████████████████▍ | 119/124 [02:46<00:06,  1.38s/it]
# Evaluating image 119
#  97%|█████████████████████████████████████▋ | 120/124 [02:48<00:05,  1.38s/it]
# Evaluating image 120
#  98%|██████████████████████████████████████ | 121/124 [02:49<00:04,  1.38s/it]
# Evaluating image 121
#  98%|██████████████████████████████████████▎| 122/124 [02:51<00:02,  1.38s/it]
# Evaluating image 122
#  99%|██████████████████████████████████████▋| 123/124 [02:52<00:01,  1.38s/it]
# Evaluating image 123
# 100%|███████████████████████████████████████| 124/124 [02:53<00:00,  1.40s/it]

# %%
import argparse
import torch
from transformers import AutoProcessor, Qwen2_5_VLForConditionalGeneration, AutoTokenizer
from qwen_vl_utils import process_vision_info
from tqdm import tqdm
import os
# Optional: only if you're using external LoRA adapters (kept separate)
try:
    from peft import PeftModel
    PEFT_AVAILABLE = True
except Exception:
    PEFT_AVAILABLE = False
# DEFAULT_QWEN25_VL_TEMPLATE = "{% set image_count = namespace(value=0) %}{% set video_count = namespace(value=0) %}{% for message in messages %}{% if loop.first and message['role'] != 'system' %}<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n{% endif %}<|im_start|>{{ message['role'] }}\n{% if message['content'] is string %}{{ message['content'] }}<|im_end|>\n{% else %}{% for content in message['content'] %}{% if content['type'] == 'image' or 'image' in content or 'image_url' in content %}{% set image_count.value = image_count.value + 1 %}{% if add_vision_id %}Picture {{ image_count.value }}: {% endif %}<|vision_start|><|image_pad|><|vision_end|>{% elif content['type'] == 'video' or 'video' in content %}{% set video_count.value = video_count.value + 1 %}{% if add_vision_id %}Video {{ video_count.value }}: {% endif %}<|vision_start|><|video_pad|><|vision_end|>{% elif 'text' in content %}{{ content['text'] }}{% endif %}{% endfor %}<|im_end|>\n{% endif %}{% endfor %}{% if add_generation_prompt %}<|im_start|>assistant\n{% endif %}"

def load_model_and_processor(
    model_id_or_path: str,
    lora_adapter: str | None = None,
    merge_lora: bool = False,
    device_map: str = "auto",
    dtype: torch.dtype | str = "auto",
):
    """
    model_id_or_path: your finetuned model (HF repo or local folder). If you merged LoRA already, just point here.
    lora_adapter: path or HF repo of LoRA adapter if NOT merged.
    merge_lora: set True to merge-and-unload LoRA into base weights for inference.
    """
    model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
        model_id_or_path,
        torch_dtype=dtype,
        device_map=device_map,
    )

    if lora_adapter:
        if not PEFT_AVAILABLE:
            raise RuntimeError("peft not installed, but lora_adapter provided.")
        model = PeftModel.from_pretrained(model, lora_adapter)
        if merge_lora:
            # Permanently merge LoRA for faster inference
            model = model.merge_and_unload()

    processor = AutoProcessor.from_pretrained(model_id_or_path)  # has the image_processor inside
    tok = AutoTokenizer.from_pretrained(model_id_or_path, use_fast=False)

    processor.tokenizer = tok 
    processor.chat_template = tok.chat_template

    return model, processor


@torch.inference_mode()
def generate_greedy(model, processor, messages,old, max_new_tokens):
    """
    messages: Chat-style list with mixed text and images, e.g.
      [{
         "role": "user",
         "content": [
            {"type": "image", "image": "file:///path/to/img.jpg" or URL or PIL.Image},
            {"type": "text", "text": "Your prompt here"}
         ]
      }]
    """
    # Prepare inputs using the official chat template and utils
    text = processor.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    )
    image_inputs, video_inputs = process_vision_info(messages)
    text += old
    # print(text)
    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    ).to(model.device)
    # Deterministic decoding: no sampling, temperature ignored (set to 0 for clarity)
    gen_ids = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False, 
        temperature=0,        
        num_beams=1,
        use_cache=True,
    )
    # Trim the prompt part before decoding
    trimmed = [out[len(inp):] for inp, out in zip(inputs.input_ids, gen_ids)]
    out_text = processor.batch_decode(trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False)
    # out_text = processor.batch_decode(gen_ids)
    return out_text[0]


def eval(model, processor, prompt, old, image, max_new_tokens=2048):
    messages = [{
        "role": "user",
        "content": [
            {"type": "image", "image": image},
            {"type": "text", "text": prompt},
        ],
    }]
    output = generate_greedy(model, processor, messages,old, max_new_tokens=max_new_tokens)
    return output


def save_evals(model, processor ,model_id):
    import numpy as np
    import json
    import random
    with open("/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/3b_vqgan_long_lr5e-5_random_blink3_long.json", "r") as f:
        previous = json.load(f)
    with open("/mmfs1/gscratch/krishna/mahtab/mmseek/vqgan/depth_codes_blink_vqgan8192.json", "r") as f:
        codes = json.load(f)
    with open("/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/New_tokens_vqgan8192.txt", "r") as f:
        tokens = [line.strip() for line in f]
    tokens= tokens[2:]
    blink3 ={}
    # blink4 ={}
    # blink5 ={}
    for i in tqdm(range(124)):
        print(f"Evaluating image {i}")
        prompt = "Multiple points are circled on the image, labeled by letters beside each circle. Which point is the closest to the camera?\nTo answer this question, let's think through it step by step, and we know the image is 336 x 336. First, what are the coordinates of points in the image? Second, what is the depth map for the image? Which point has a higher pixel value on the depth map? Remember, higher values indicate that the point is closer to the camera."
        typ ="long"
        # prompt = "Multiple points are circled on the image, labeled by letters beside each circle. Which point is the closest to the camera?"
        # typ = "short"
        # prompt = "Multiple points are circled on the image, labeled by letters beside each circle. Which point is the closest to the camera?\nTo answer this question, let's think through it step by step, and we know the image is 336 x 336. First, what are the coordinates of points in the image? Which point has a higher pixel value on the depth map? Remember, higher values indicate that the point is closer to the camera."
        # typ = "onlytext"
        # prompt = "What is the depth map for this image?"
        # typ = "depth"
        # prompt = "What do you see in this image?"
        # typ = "free"
        ##blink3
        image = f"/mmfs1/gscratch/krishna/mahtab/Aurora-perception/Data/evals/hardblink/images/blink3pointscenter/{i}.png"
        assert os.path.exists(image), f"Image {image} does not exist"
        try:
            old =  previous[str(i)]
            # code = codes[f"{i}_depth.png"]
            code = "<DEPTH_START>" +  "".join([random.choice(tokens) for i in range(1024)])   + "<DEPTH_END>"
            old =  old.split("<DEPTH_START>")[0] + code
            # old =  old.split("<DEPTH_END>")[0] + "<DEPTH_END>"
            output = eval(model, processor, prompt, old, image)
            import pdb; pdb.set_trace()
            blink3[i] = output
        except Exception as e:
            pass
        # print(output)
        ##blink4
        # image = f"/mmfs1/gscratch/krishna/mahtab/Aurora-perception/Data/evals/hardblink/images/blink4pointscenter/{i}.png"
        # assert os.path.exists(image), f"Image {image} does not exist"
        # try:
        #     old =  previous[str(i)]
        #     code = codes[f"{i}_depth.png"]
        #     # code = "<DEPTH_START>" +  "".join([f"<DEPTH_{random.randint(0, 127)}>" for i in range(100)])   + "<DEPTH_END>"
        #     old =  old.split("<DEPTH_START>")[0] + code
        #     # old =  old.split("<DEPTH_END>")[0] + "<DEPTH_END>"
        #     output = eval(model, processor, prompt, old, image)
        #     blink4[i] = output
        # except Exception as e:
        #     pass
        # ##blink5
        # image = f"/mmfs1/gscratch/krishna/mahtab/Aurora-perception/Data/evals/hardblink/images/blink5pointscenter/{i}.png"
        # assert os.path.exists(image), f"Image {image} does not exist"
    
        # old =  previous[str(i)]
        # # code = codes[f"{i}_depth.png"]
        # code = "<DEPTH_START>" +  "".join([f"<DEPTH_{random.randint(0, 127)}>" for i in range(100)])   + "<DEPTH_END>"
        # old =  old.split("<DEPTH_START>")[0] + code
        # # old =  old.split("<DEPTH_END>")[0] + "<DEPTH_END>"
        # output = eval(model, processor, prompt, old, image)
        # blink5[i] = output
        
    
        # import json
        with open(f"/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/{model_id}_blink3_{typ}_withrandom.json", "w") as f:
            json.dump(blink3, f)
        # with open(f"/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/{model_id}_blink4_{typ}_withgt.json", "w") as f:
        #     json.dump(blink4, f)
        # with open(f"/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/{model_id}_blink5_{typ}_withrandom.json", "w") as f:
        #     json.dump(blink5, f)
    
    # print(len(blink3), len(blink4), len(blink5))






        





def main():
    parser = argparse.ArgumentParser()
    lora_adapter = None
    merge_lora = False

    model_name =  "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/checkpoints/3b_vqgan_long_lr5e-5_random"  
    # model_name = "Qwen/Qwen2.5-VL-7B-Instruct"
    dtype = torch.bfloat16 if torch.cuda.is_available() else "auto"
    model, processor = load_model_and_processor(
        model_name,
        lora_adapter=lora_adapter,
        merge_lora=merge_lora,
        dtype=dtype,
        device_map="auto"
    )
    save_evals(model, processor, model_name.split("/")[-1])



if __name__ == "__main__":
    main()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|                                           | 0/124 [00:00<?, ?it/s]/gscratch/krishna/mahtab/miniconda3/envs/qwen2vl/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:631: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Evaluating image 0
#   1%|▎                                  | 1/124 [00:01<02:49,  1.38s/it]
# Evaluating image 1
#   2%|▌                                  | 2/124 [00:02<02:48,  1.38s/it]
# Evaluating image 2
#   2%|▊                                  | 3/124 [00:04<02:46,  1.38s/it]
# Evaluating image 3
#   3%|█▏                                 | 4/124 [00:05<02:45,  1.38s/it]
# Evaluating image 4
#   4%|█▍                                 | 5/124 [00:06<02:43,  1.38s/it]
# Evaluating image 5
#   5%|█▋                                 | 6/124 [00:08<02:42,  1.38s/it]
# Evaluating image 6
#   6%|█▉                                 | 7/124 [00:09<02:40,  1.37s/it]
# Evaluating image 7
#   6%|██▎                                | 8/124 [00:10<02:39,  1.37s/it]
# Evaluating image 8
#   7%|██▌                                | 9/124 [00:12<02:37,  1.37s/it]
# Evaluating image 9
#   8%|██▋                               | 10/124 [00:13<02:36,  1.37s/it]
# Evaluating image 10
#   9%|███                               | 11/124 [00:15<02:35,  1.37s/it]
# Evaluating image 11
#  10%|███▎                              | 12/124 [00:16<02:33,  1.37s/it]
# Evaluating image 12
#  10%|███▌                              | 13/124 [00:17<02:32,  1.38s/it]
# Evaluating image 13
#  11%|███▊                              | 14/124 [00:19<02:31,  1.37s/it]
# Evaluating image 14
#  12%|████                              | 15/124 [00:20<02:29,  1.37s/it]
# Evaluating image 15
#  13%|████▍                             | 16/124 [00:21<02:28,  1.37s/it]
# Evaluating image 16
#  14%|████▋                             | 17/124 [00:23<02:26,  1.37s/it]
# Evaluating image 17
#  15%|████▉                             | 18/124 [00:24<02:25,  1.37s/it]
# Evaluating image 18
#  15%|█████▏                            | 19/124 [00:26<02:24,  1.38s/it]
# Evaluating image 19
#  16%|█████▍                            | 20/124 [00:27<02:22,  1.37s/it]
# Evaluating image 20
#  17%|█████▊                            | 21/124 [00:28<02:20,  1.37s/it]
# Evaluating image 21
#  18%|██████                            | 22/124 [00:30<02:19,  1.37s/it]
# Evaluating image 22
#  19%|██████▎                           | 23/124 [00:31<02:18,  1.37s/it]
# Evaluating image 23
#  19%|██████▌                           | 24/124 [00:32<02:16,  1.37s/it]
# Evaluating image 24
#  20%|██████▊                           | 25/124 [00:34<02:15,  1.37s/it]
# Evaluating image 25
#  21%|███████▏                          | 26/124 [00:35<02:14,  1.38s/it]
# Evaluating image 26
#  22%|███████▍                          | 27/124 [00:37<02:13,  1.38s/it]
# Evaluating image 27
#  23%|███████▋                          | 28/124 [00:38<02:12,  1.38s/it]
# Evaluating image 28
#  23%|███████▉                          | 29/124 [00:39<02:11,  1.38s/it]
# Evaluating image 29
#  24%|████████▏                         | 30/124 [00:41<02:09,  1.37s/it]
# Evaluating image 30
#  25%|████████▌                         | 31/124 [00:42<02:07,  1.37s/it]
# Evaluating image 31
#  26%|████████▊                         | 32/124 [00:43<02:05,  1.37s/it]
# Evaluating image 32
#  27%|█████████                         | 33/124 [00:45<02:04,  1.37s/it]
# Evaluating image 33
#  27%|█████████▎                        | 34/124 [00:46<02:02,  1.36s/it]
# Evaluating image 34
#  28%|█████████▌                        | 35/124 [00:48<02:01,  1.36s/it]
# Evaluating image 35
#  29%|█████████▊                        | 36/124 [00:49<02:00,  1.37s/it]
# Evaluating image 36
#  30%|██████████▏                       | 37/124 [00:50<01:58,  1.37s/it]
# Evaluating image 37
#  31%|██████████▍                       | 38/124 [00:52<01:57,  1.36s/it]
# Evaluating image 38
#  31%|██████████▋                       | 39/124 [00:53<01:55,  1.36s/it]
# Evaluating image 39
#  32%|██████████▉                       | 40/124 [00:54<01:54,  1.36s/it]
# Evaluating image 40
#  33%|███████████▏                      | 41/124 [00:56<01:52,  1.36s/it]
# Evaluating image 41
#  34%|███████████▌                      | 42/124 [00:57<01:51,  1.36s/it]
# Evaluating image 42
#  35%|███████████▊                      | 43/124 [00:58<01:50,  1.36s/it]
# Evaluating image 43
#  35%|████████████                      | 44/124 [01:00<01:48,  1.36s/it]
# Evaluating image 44
#  36%|████████████▎                     | 45/124 [01:01<01:47,  1.36s/it]
# Evaluating image 45
#  37%|████████████▌                     | 46/124 [01:03<01:46,  1.36s/it]
# Evaluating image 46
#  38%|████████████▉                     | 47/124 [01:04<01:44,  1.36s/it]
# Evaluating image 47
#  39%|█████████████▏                    | 48/124 [01:05<01:43,  1.36s/it]
# Evaluating image 48
#  40%|█████████████▍                    | 49/124 [01:07<01:42,  1.36s/it]
# Evaluating image 49
#  40%|█████████████▋                    | 50/124 [01:08<01:40,  1.36s/it]
# Evaluating image 50
#  41%|█████████████▉                    | 51/124 [01:09<01:39,  1.36s/it]
# Evaluating image 51
#  42%|██████████████▎                   | 52/124 [01:11<01:37,  1.36s/it]
# Evaluating image 52
#  43%|██████████████▌                   | 53/124 [01:12<01:36,  1.36s/it]
# Evaluating image 53
#  44%|██████████████▊                   | 54/124 [01:13<01:35,  1.36s/it]
# Evaluating image 54
#  44%|███████████████                   | 55/124 [01:15<01:33,  1.36s/it]
# Evaluating image 55
#  45%|███████████████▎                  | 56/124 [01:16<01:32,  1.36s/it]
# Evaluating image 56
#  46%|███████████████▋                  | 57/124 [01:17<01:31,  1.36s/it]
# Evaluating image 57
#  47%|███████████████▉                  | 58/124 [01:19<01:29,  1.36s/it]
# Evaluating image 58
#  48%|████████████████▏                 | 59/124 [01:20<01:28,  1.36s/it]
# Evaluating image 59
#  48%|████████████████▍                 | 60/124 [01:22<01:27,  1.36s/it]
# Evaluating image 60
#  49%|████████████████▋                 | 61/124 [01:23<01:25,  1.36s/it]
# Evaluating image 61
