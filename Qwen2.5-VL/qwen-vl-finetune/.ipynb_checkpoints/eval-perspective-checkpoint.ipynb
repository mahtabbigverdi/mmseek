# %%
val_data_path  = "/mmfs1/gscratch/krishna/mahtab/mmseek/Data/validation_perspective.json"
import json
with open(val_data_path, 'r') as f:
    val_data = json.load(f)

# %%
# pred_path ="/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/perspective/Qwen2.5-VL-3B-Instruct_perspective_answers.json"
pred_path = "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/perspective/3b_perspective_image1024_10epochs_lr5e5_random_perspective_answers.json"
with open(pred_path, 'r') as f:
    predictions = json.load(f)

# %%
acc, total = 0,0
for item in val_data:
    index = str(item['id'])
    answer = item['conversations'][1]['value']
    pred = predictions[index]
    #.split("\n")[-1].split("oxed{")[-1]
    # .split("\n")[-1]
    
    if answer in pred:
        acc+=1
        # print(index, pred[-20:], answer)
    else:
        pass
        # if answer[0] in pred:
        #     print(answer, pred, index)
        # print(index, pred[-20:], answer)
    total +=1


acc, total, acc/total*100.0
# Out:
# (201, 400, 50.24999999999999)
