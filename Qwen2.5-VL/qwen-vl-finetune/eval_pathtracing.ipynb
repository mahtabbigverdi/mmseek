# %%
val_data_path  = "/mmfs1/gscratch/krishna/mahtab/mmseek/Data/validation_path_tracing_2point.json"
import json
with open(val_data_path, 'r') as f:
    val_data = json.load(f)

# %%
pred_path = "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/3b_path_tracing_2points_graythought_vqgan1024_10epochs_lr5e-5_random_path_tracing_2point_answers.json"
with open(pred_path, 'r') as f:
    predictions = json.load(f)

# %%
acc, total = 0,0
for item in val_data:
    index = str(item['id'])
    answer = item['conversations'][1]['value']
    pred = predictions[index].split("\n")[-1]
    if answer in pred:
        acc+=1
        # print(index, pred, answer)
    else:
        pass
        # print(index, pred[-20:], answer)
    total +=1


acc, total, acc/total*100.0
# Out:
# (65, 109, 59.63302752293578)

# %%
pred_path = "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/7b_path_tracing_2points_vqgan1024_mmthought_10epochs_lr5e-5_random_path_tracing_2point_answers.json"
with open(pred_path, 'r') as f:
    predictions = json.load(f)

# %%
acc, total = 0,0
for item in val_data:
    index = str(item['id'])
    answer = item['conversations'][1]['value']
    pred = predictions[index]
    if answer in pred:
        acc+=1
        # print(index, pred, answer)
    else:
        pass
        # print(index, pred, answer)
    total +=1


acc, total, acc/total*100.0
# Out:
# (41, 109, 37.61467889908257)

# %%
pred_path = "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen2.5-VL/qwen-vl-finetune/outputs/3b_path_tracing_2points_vqgan16384_mm_10epochs_lr5e-5_random_path_tracing_2point_answers.json"
with open(pred_path, 'r') as f:
    predictions = json.load(f)

# %%
val_data_path  = "/mmfs1/gscratch/krishna/mahtab/mmseek/optical_flow/data/val_data.json"
import json
with open(val_data_path, 'r') as f:
    val_data = json.load(f)

# %%
pred_path = "/mmfs1/gscratch/krishna/mahtab/mmseek/Qwen3-VL/qwen3vl_video_val_answers.json"
with open(pred_path, 'r') as f:
    predictions = json.load(f)

# %%
acc, total = 0,0
for item in val_data:
    index = str(item['id'])
    answer = item['conversations'][1]['value'].lower()[0]
    pred = predictions[index].split("oxed")[-1].replace("text", "")
    if answer in pred:
        acc+=1
        # print( index, pred, answer)
    else:
        pass
        print(index, pred, answer)
    total +=1


acc, total, acc/total*100.0
# Out:
# 28 {\{b}}\} a
# 131 {\{a}}\} b
# 144 {\{b}}\} a
# 222 {\{b}}\} a
# 446 {\{b}}\} a
# 507 {a}\} b
# 520 {\{b}}\} a
# 567 {\{a}}\} b
# 752 {\{b}}\} a
# 816 {\{b}}\} a
# 825 {\{a}}\} b
# 958 {\{b}}\} a
# 1141 {\{a}}\} b
# 1230 {\{b}}\} a
# 1320 {\{b}}\} a
# 1384 {\{b}}\} a
# 1504 {\{b}}\} a
# 1642 {\{b}}\} a
# 1840 {\{b}}\} a
# 1846 {\{b}}\} a
# 2034 {\{b}}\} a
# 2123 {\{a}}\} b
# 2128 {\{b}}\} a
# 2260 {\{b}}\} a
# 2267 {\{a}}\} b
# 2318 {\{b}}\} a
# 2340 {\{b}}\} a
# 2414 {\{b}}\} a
# 2430 {\{b}}\} a
# 2558 {\{b}}\} a
# 2800 {\{b}}\} a
# 3193 {\{a}}\} b
# 3218 {\{b}}\} a
# 3228 {\{b}}\} a
# 3304 {\{b}}\} a
# 3316 {\{b}}\} a
# 3392 {\{b}}\} a
# 3416 {\{b}}\} a
# 3492 {\{b}}\} a
# 3549 {\{a}}\} b
# 3576 {\{b}}\} a
# (59, 100, 59.0)
